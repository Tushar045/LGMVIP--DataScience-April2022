# %% [markdown]
# LetsGrowMore Virtual Internship Program
#
# Task 2 : Image to Pencil Sketch with Python
#
# Level : Beginner
#
# In these task, we have to convert a given image into its pencil sketch using python. In these we use CV ( Computer Vision ) library and Pillow module for the Image Processing.
#
# Importing Libraries

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %%
img  =  cv2.imread("C:\\Users\\Tushar Nikam\\Downloads\\wallpapertip_gambar-wallpaper-anime_1896080.png")
img = cv2.resize(img,(200,300))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x2033D2A8970>

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x2033D6BE6A0>

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x2033BC3DCA0>

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x2033BC4CFD0>

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x2033D54EEB0>

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x2033D6BE6A0>
# <PIL.Image.Image image mode=L size=200x300 at 0x2033BB9EFA0>
